# %% [markdown]
# ## Yolo V3 with Tensorflow

# %%
from train.train_multigpu import *
% load_ext autoreload
% autoreload 2

# %%
model_train = YOLO_TRAIN(cfg.path.train_data_path, gpus = [0], num_gpus = 1)

# %%
model_train.build_model()
# Out:
# darknet
# (?, 608, 608, 3)
# /home/tsimage-x/anaconda3/envs/tensorflow-work/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Tensor("TOWER_0/total_loss:0", shape=(), dtype=float32, device=/device:GPU:0)
# ****************************************
# <class 'tensorflow.python.framework.ops.Tensor'>
# #############################
# ...

# %%
model_train.train_model()
# Out:
# no checkpoint found
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow-work/lib/python3.5/site-packages/tensorflow/python/client/session.py in __init__(self, fetches, contraction_fn)
#     281         self._unique_fetches.append(ops.get_default_graph().as_graph_element(
# --> 282             fetch, allow_tensor=True, allow_operation=True))
#     283       except TypeError as e:
#
# ~/anaconda3/envs/tensorflow-work/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in as_graph_element(self, obj, allow_tensor, allow_operation)
#    3589     with self._lock:
# -> 3590       return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    3591
#
# ~/anaconda3/envs/tensorflow-work/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in _as_graph_element_locked(self, obj, allow_tensor, allow_operation)
# ...
